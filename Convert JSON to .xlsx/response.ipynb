# %%
# !pip install openpyxl pandas

# %%
import pandas as pd

df = pd.read_json("../response.json")
df = pd.json_normalize(df['list_of_all_tasks'])
df
# Out:
#           MSCW                 Area      Module  \
# 0  1 Must Have  01 Analyze & Design     Overall
# 1  1 Must Have             03 Setup       Infra
# 2  1 Must Have       04 Development    Frontend
# 3  1 Must Have       04 Development  Middleware
# 4  1 Must Have       04 Development  Middleware
# 5  1 Must Have       04 Development  Middleware
# 6  1 Must Have       04 Development  Middleware
# 7  1 Must Have       04 Development  Middleware
# 8  1 Must Have       04 Development     Backend
# 9  1 Must Have       04 Development     Backend
#
#                            Feature  \
# 0               Technical Analysis
# 1        Setup Environment + Azure
# 2              User Interface (UI)
# 3  Authentication & Authorizations
# 4               Filtering / search
# 5                    Notifications
# 6             APIs for Data Access
# 7    Appointment Scheduling System
# 8               Listing Management
# 9            Analytics & Reporting
#
# ...

# %%
df.to_csv('response.csv', index=False)
df.to_excel('response.xlsx', index=False, sheet_name="Tasks", engine='openpyxl')
